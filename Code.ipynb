# %% [markdown]
# <a href="https://colab.research.google.com/github/rezaulcmt/Data_Science_Project_Rezaul/blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization and Preprocessing

# %%
import torch  # Import PyTorch for creating and training models.
import torchvision  # Import torchvision for datasets and utilities.
import torchvision.transforms as transforms  # Import transforms for image preprocessing.
import matplotlib.pyplot as plt  # Import Matplotlib for plotting.
import numpy as np  # Import NumPy for numerical computations.

# Define transformations for preprocessing the images.
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor format.
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize image values to [-1, 1].
])

# Load the CIFAR-100 training dataset with transformations.
cifar100_trainset = torchvision.datasets.CIFAR100(
    root='./data',  # Directory where the dataset is stored.
    train=True,  # Indicate that we want the training data.
    download=True,  # Download the dataset if not already present.
    transform=transform  # Apply the defined transformations.
)
cifar100_classes = cifar100_trainset.classes  # Get the class names for CIFAR-100.

# Load the SVHN training dataset with transformations.
svhn_trainset = torchvision.datasets.SVHN(
    root='./data',  # Directory where the dataset is stored.
    split='train',  # Indicate that we want the training split.
    download=True,  # Download the dataset if not already present.
    transform=transform  # Apply the defined transformations.
)

# Define a function to display images and labels.
def imshow(img, labels, classes, title):
    img = img / 2 + 0.5  # Unnormalize the image to bring pixel values to [0, 1].
    npimg = img.numpy()  # Convert the tensor to a NumPy array.
    plt.figure(figsize=(10, 10))  # Set the size of the displayed plot.
    plt.imshow(np.transpose(npimg, (1, 2, 0)))  # Adjust dimensions for proper visualization.
    plt.title(title)  # Set the title of the plot.
    plt.show()  # Display the plot.

# Create a DataLoader for CIFAR-100 to load data in batches.
data_loader_cifar100 = torch.utils.data.DataLoader(
    cifar100_trainset,  # Specify the dataset to load.
    batch_size=4,  # Number of samples in each batch.
    shuffle=True  # Shuffle the data at each epoch.
)
dataiter_cifar100 = iter(data_loader_cifar100)  # Create an iterator for the data loader.
images_cifar100, labels_cifar100 = next(dataiter_cifar100)  # Fetch the next batch of images and labels.

# Convert numerical labels to class names for CIFAR-100.
cifar100_label_names = [cifar100_classes[label] for label in labels_cifar100]

# Display a batch of CIFAR-100 images with class names as the title.
imshow(
    torchvision.utils.make_grid(images_cifar100),  # Combine multiple images into a single grid.
    labels_cifar100,  # Provide the batch labels.
    cifar100_classes,  # List of all class names for translation.
    f"CIFAR-100: {', '.join(cifar100_label_names)}"  # Format title with class names.
)

# Create a DataLoader for SVHN to load data in batches.
data_loader_svhn = torch.utils.data.DataLoader(
    svhn_trainset,  # Specify the dataset to load.
    batch_size=4,  # Number of samples in each batch.
    shuffle=True  # Shuffle the data at each epoch.
)
dataiter_svhn = iter(data_loader_svhn)  # Create an iterator for the data loader.
images_svhn, labels_svhn = next(dataiter_svhn)  # Fetch the next batch of images and labels.

# Display a batch of SVHN images with numerical labels as the title.
imshow(
    torchvision.utils.make_grid(images_svhn),  # Combine multiple images into a single grid.
    labels_svhn,  # Provide the batch labels.
    [str(i) for i in range(10)],  # List of numerical class names for SVHN.
    f"SVHN: {', '.join(labels_svhn.numpy().astype(str))}"  # Format title with numerical labels.
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:05<00:00, 30.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to ./data/train_32x32.mat
# 100%|██████████| 182M/182M [00:49<00:00, 3.68MB/s]

# %%
from collections import Counter  # Import Counter for counting occurrences in lists.
import torchvision  # Import torchvision for datasets and utilities.
import torchvision.transforms as transforms  # Import transforms for image preprocessing.

# Define image transformations: convert to tensor and normalize.
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor format.
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize values to [-1, 1].
])

# Load the CIFAR-100 training dataset with transformations.
cifar100_trainset = torchvision.datasets.CIFAR100(
    root='./data',  # Directory where the dataset is stored.
    train=True,  # Indicate that we want the training data.
    download=True,  # Download the dataset if not already present.
    transform=transform  # Apply the defined transformations.
)

# Get all labels from the CIFAR-100 dataset.
cifar100_labels = cifar100_trainset.targets  # List of numerical labels (indices).
cifar100_label_names = [cifar100_classes[label] for label in cifar100_labels]  # Map labels to class names.

# Count how many samples exist for each class.
cifar100_class_counts = Counter(cifar100_label_names)  # Count occurrences of each class name.

# Print the number of samples for each class.
print("CIFAR-100 Class Counts:")  # Header for output.
for class_name, count in cifar100_class_counts.items():  # Loop through class counts.
    print(f"{class_name}: {count}")  # Print the class name and its count.
# Out:
# Files already downloaded and verified
# CIFAR-100 Class Counts:
# cattle: 500
# dinosaur: 500
# apple: 500
# boy: 500
# aquarium_fish: 500
# telephone: 500
# train: 500
# cup: 500
# cloud: 500
# elephant: 500
# keyboard: 500
# willow_tree: 500
# sunflower: 500
# castle: 500
# sea: 500
# bicycle: 500
# wolf: 500
# squirrel: 500
# shrew: 500
# pine_tree: 500
# rose: 500
# television: 500
# table: 500
# possum: 500
# oak_tree: 500
# leopard: 500
# maple_tree: 500
# rabbit: 500
# chimpanzee: 500
# clock: 500
# streetcar: 500
# cockroach: 500
# snake: 500
# lobster: 500
# mountain: 500
# palm_tree: 500
# skyscraper: 500
# tractor: 500
# shark: 500
# butterfly: 500
# bottle: 500
# bee: 500
# chair: 500
# woman: 500
# hamster: 500
# otter: 500
# seal: 500
# lion: 500
# mushroom: 500
# girl: 500
# sweet_pepper: 500
# forest: 500
# crocodile: 500
# orange: 500
# tulip: 500
# mouse: 500
# camel: 500
# caterpillar: 500
# man: 500
# skunk: 500
# kangaroo: 500
# raccoon: 500
# snail: 500
# rocket: 500
# whale: 500
# worm: 500
# turtle: 500
# beaver: 500
# plate: 500
# wardrobe: 500
# road: 500
# fox: 500
# flatfish: 500
# tiger: 500
# ray: 500
# dolphin: 500
# poppy: 500
# porcupine: 500
# lamp: 500
# crab: 500
# motorcycle: 500
# spider: 500
# tank: 500
# orchid: 500
# lizard: 500
# beetle: 500
# bridge: 500
# baby: 500
# lawn_mower: 500
# house: 500
# bus: 500
# couch: 500
# bowl: 500
# pear: 500
# bed: 500
# plain: 500
# trout: 500
# bear: 500
# pickup_truck: 500
# can: 500

# %% [markdown]
# #CIFAR100

# %% [markdown]
# ResNet50

# %%
import torch  # Import PyTorch for neural networks and tensor operations.
import torch.nn as nn  # Import PyTorch's neural network modules.
import torch.optim as optim  # Import optimization algorithms.
import torchvision  # Import torchvision for datasets and pretrained models.
import torchvision.transforms as transforms  # Import transforms for preprocessing image data.
import matplotlib.pyplot as plt  # Import Matplotlib for plotting.
import numpy as np  # Import NumPy for numerical operations.
from torchvision import models  # Import torchvision models.
import random  # Import random for random number generation.

# Set random seeds for reproducibility across runs.
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():  # For CUDA-enabled devices, set additional seeds.
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior.
    torch.backends.cudnn.benchmark = False  # Disable benchmark mode.

# Specify the device to use: GPU if available, otherwise CPU.
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Define transformations for training and testing data.
transform_train = transforms.Compose([
    transforms.Resize(224),  # Resize images to 224x224 (ResNet input size).
    transforms.ToTensor(),  # Convert images to PyTorch tensors.
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),  # Normalize based on CIFAR-100 stats.
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

# Load CIFAR-100 training and testing datasets with transformations.
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load a pretrained ResNet50 model and modify the final layer for 100 classes.
print('==> Loading pretrained ResNet50 model..')
net = models.resnet50(pretrained=True)
net.fc = nn.Linear(net.fc.in_features, 100)  # Replace the final fully connected layer.
net = net.to(device)  # Move the model to the selected device.

# Set up loss function and optimizer for training.
criterion = nn.CrossEntropyLoss()  # Use cross-entropy loss for classification.
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

# Fine-tune the model on the CIFAR-100 training dataset.
print("==> Starting fine-tuning on CIFAR-100..")
for epoch in range(25):  # Train for 25 epochs.
    net.train()  # Set the model to training mode.
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):  # Iterate over training batches.
        inputs, targets = inputs.to(device), targets.to(device)  # Move inputs and targets to device.
        optimizer.zero_grad()  # Reset gradients.
        outputs = net(inputs)  # Forward pass.
        loss = criterion(outputs, targets)  # Compute loss.
        loss.backward()  # Backpropagation.
        optimizer.step()  # Update model parameters.

        train_loss += loss.item()
        _, predicted = outputs.max(1)  # Get class predictions.
        total += targets.size(0)  # Total samples in the batch.
        correct += predicted.eq(targets).sum().item()  # Count correct predictions.

    # Print training progress for the epoch.
    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define the FGSM attack.
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)  # Create adversarial input.
    output = model(x_adv)  # Forward pass.
    loss = criterion(output, y)  # Compute loss.
    model.zero_grad()
    loss.backward()  # Compute gradients.
    x_adv = x_adv + epsilon * x_adv.grad.sign()  # Apply FGSM update.
    x_adv = torch.clamp(x_adv, 0, 1)  # Ensure pixel values remain valid.
    return x_adv

# Define the PGD attack.
def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)  # Create adversarial input.
    for _ in range(num_iter):  # Perform multiple iterations.
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()  # Apply PGD update.
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)  # Restrict perturbation size.
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Define the Carlini-Wagner attack.
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.01):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach().requires_grad_(True)
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):  # Perform multiple iterations.
        outputs = model(adv_images)
        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            f_loss = torch.max((correct_class - outputs + kappa).clamp(min=0), 1).values.mean()

        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        adv_images.data = torch.clamp(adv_images.data, 0, 1)  # Ensure pixel values remain valid.

    return adv_images

# Evaluate the model on adversarial or clean inputs.
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        # Apply the specified attack if provided.
        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total  # Compute accuracy.
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate the model on clean inputs.
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Set parameters for FGSM, PGD, and C&W attacks.
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Evaluate the model under FGSM, PGD, and C&W attacks.
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot the accuracy results for clean and adversarial examples.
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained ResNet50 Accuracy on Clean and Adversarial Examples (CIFAR-100)')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Loading pretrained ResNet50 model..
# ==> Starting fine-tuning on CIFAR-100..
# Epoch 1: Train Loss: 2.728 | Train Accuracy: 44.64%
# Epoch 2: Train Loss: 0.987 | Train Accuracy: 74.56%
# Epoch 3: Train Loss: 0.654 | Train Accuracy: 81.86%
# Epoch 4: Train Loss: 0.472 | Train Accuracy: 86.89%
# Epoch 5: Train Loss: 0.345 | Train Accuracy: 90.87%
# Epoch 6: Train Loss: 0.249 | Train Accuracy: 93.78%
# Epoch 7: Train Loss: 0.177 | Train Accuracy: 96.10%
# Epoch 8: Train Loss: 0.121 | Train Accuracy: 97.83%
# Epoch 9: Train Loss: 0.085 | Train Accuracy: 98.72%
# Epoch 10: Train Loss: 0.060 | Train Accuracy: 99.40%
# Epoch 11: Train Loss: 0.042 | Train Accuracy: 99.74%
# Epoch 12: Train Loss: 0.032 | Train Accuracy: 99.83%
# Epoch 13: Train Loss: 0.025 | Train Accuracy: 99.89%
# Epoch 14: Train Loss: 0.021 | Train Accuracy: 99.92%
# Epoch 15: Train Loss: 0.018 | Train Accuracy: 99.93%
# Epoch 16: Train Loss: 0.015 | Train Accuracy: 99.94%
# Epoch 17: Train Loss: 0.013 | Train Accuracy: 99.97%
# Epoch 18: Train Loss: 0.012 | Train Accuracy: 99.96%
# Epoch 19: Train Loss: 0.011 | Train Accuracy: 99.97%
# Epoch 20: Train Loss: 0.010 | Train Accuracy: 99.97%
# Epoch 21: Train Loss: 0.009 | Train Accuracy: 99.97%
# Epoch 22: Train Loss: 0.008 | Train Accuracy: 99.97%
# Epoch 23: Train Loss: 0.008 | Train Accuracy: 99.98%
# Epoch 24: Train Loss: 0.007 | Train Accuracy: 99.97%
# Epoch 25: Train Loss: 0.007 | Train Accuracy: 99.98%
# ==> Evaluating on clean images..
# Accuracy on clean images: 81.38%
# Accuracy on FGSM adversarial examples: 29.92%
# Accuracy on PGD adversarial examples: 7.23%
# Accuracy on CW adversarial examples: 2.01%

# %% [markdown]
# VGG19

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision import models
import random

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare CIFAR-100 data
transform_train = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load pretrained VGG19 model and adjust for CIFAR-100
print('==> Loading pretrained VGG19 model..')
net = models.vgg19(pretrained=True)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 100)  # Adjust final layer for CIFAR-100
net = net.to(device)

# Fine-tune the model on CIFAR-100
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Starting fine-tuning on CIFAR-100..")
for epoch in range(5):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define FGSM and PGD attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Carlini-Wagner attack function
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.01):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach()
    adv_images.requires_grad = True
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):
        outputs = model(adv_images)

        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            f_loss = torch.max((correct_class - outputs + kappa).clamp(min=0), 1).values.mean()

        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        adv_images.data = torch.clamp(adv_images.data, 0, 1)

    return adv_images

# Test function to evaluate model accuracy on clean or adversarial examples
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate on clean images
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Parameters for FGSM, PGD, and C&W attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Testing the pretrained VGG19 model on FGSM, PGD, and C&W attacks
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained VGG19 Accuracy on Clean and Adversarial Examples (CIFAR-100)')
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:01<00:00, 104MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Loading pretrained VGG19 model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 217MB/s]
# ==> Starting fine-tuning on CIFAR-100..
# Epoch 1: Train Loss: 2.043 | Train Accuracy: 47.05%
# Epoch 2: Train Loss: 1.070 | Train Accuracy: 68.21%
# Epoch 3: Train Loss: 0.836 | Train Accuracy: 74.52%
# Epoch 4: Train Loss: 0.679 | Train Accuracy: 78.87%
# Epoch 5: Train Loss: 0.551 | Train Accuracy: 82.53%
# ==> Evaluating on clean images..
# Accuracy on clean images: 71.93%
# Accuracy on FGSM adversarial examples: 8.41%
# Accuracy on PGD adversarial examples: 3.09%
# Accuracy on CW adversarial examples: 10.74%

# %% [markdown]
# MobileNetV2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision import models
import random

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare CIFAR-100 data
transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale to 224x224 to match ImageNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load pretrained MobileNetV2 model and adjust for CIFAR-100
print('==> Loading pretrained MobileNetV2 model..')
net = models.mobilenet_v2(pretrained=True)
net.classifier[1] = nn.Linear(net.last_channel, 100)
net = net.to(device)

# Fine-tune the model on CIFAR-100
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Starting fine-tuning on CIFAR-100..")
for epoch in range(5):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define FGSM and PGD attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Carlini-Wagner attack function
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.01):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach()
    adv_images.requires_grad = True
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):
        outputs = model(adv_images)

        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            f_loss = torch.max((correct_class - outputs + kappa).clamp(min=0), 1).values.mean()

        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        adv_images.data = torch.clamp(adv_images.data, 0, 1)

    return adv_images

# Test function to evaluate model accuracy on clean or adversarial examples
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate on clean images
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Parameters for FGSM, PGD, and C&W attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Testing the pretrained MobileNetV2 model on FGSM, PGD, and C&W attacks
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained MobileNetV2 Accuracy on Clean and Adversarial Examples (CIFAR-100)')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Loading pretrained MobileNetV2 model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 84.7MB/s]
# ==> Starting fine-tuning on CIFAR-100..
# Epoch 1: Train Loss: 2.985 | Train Accuracy: 33.94%
# Epoch 2: Train Loss: 1.464 | Train Accuracy: 62.25%
# Epoch 3: Train Loss: 1.071 | Train Accuracy: 70.57%
# Epoch 4: Train Loss: 0.868 | Train Accuracy: 75.69%
# Epoch 5: Train Loss: 0.729 | Train Accuracy: 79.15%
# ==> Evaluating on clean images..
# Accuracy on clean images: 74.42%
# Accuracy on FGSM adversarial examples: 29.41%
# Accuracy on PGD adversarial examples: 3.28%
# Accuracy on CW adversarial examples: 2.93%

# %% [markdown]
# #SVHN Dataset

# %% [markdown]
# Resnet50

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision import models
import random

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare SVHN dataset
from torchvision.datasets import SVHN

transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale to 224x224 to match ImageNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

trainset = SVHN(root='./data', split='train', download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = SVHN(root='./data', split='test', download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load pretrained ResNet50 model and adjust for SVHN
print('==> Loading pretrained ResNet50 model..')
net = models.resnet50(pretrained=True)
net.fc = nn.Linear(net.fc.in_features, 10)  # Adjust final layer for SVHN (10 classes)
net = net.to(device)

# Fine-tune the model on SVHN
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Starting fine-tuning on SVHN..")
for epoch in range(5):  # Adjust number of epochs as needed
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define FGSM and PGD attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Carlini-Wagner attack function
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.01):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach()
    adv_images.requires_grad = True
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):
        outputs = model(adv_images)

        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            #f_loss = torch.max((correct_class - outputs + kappa).clamp(min=0), 1).values.mean()
            f_loss = torch.max((correct_class.unsqueeze(1) - outputs + kappa).clamp(min=0), dim=1)[0].mean()


        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        adv_images.data = torch.clamp(adv_images.data, 0, 1)

    return adv_images

# Test function to evaluate model accuracy on clean or adversarial examples
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate on clean images
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Parameters for FGSM, PGD, and C&W attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Testing the pretrained ResNet50 model on FGSM, PGD, and C&W attacks
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained ResNet50 Accuracy on Clean and Adversarial Examples (SVHN)')
plt.show()
# Out:
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to ./data/train_32x32.mat
# 100%|██████████| 182M/182M [00:58<00:00, 3.12MB/s]
# Downloading http://ufldl.stanford.edu/housenumbers/test_32x32.mat to ./data/test_32x32.mat
# 100%|██████████| 64.3M/64.3M [00:19<00:00, 3.33MB/s]
# ==> Loading pretrained ResNet50 model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 216MB/s]
# ==> Starting fine-tuning on SVHN..
# Epoch 1: Train Loss: 0.726 | Train Accuracy: 76.53%
# Epoch 2: Train Loss: 0.210 | Train Accuracy: 93.87%
# Epoch 3: Train Loss: 0.154 | Train Accuracy: 95.66%
# Epoch 4: Train Loss: 0.114 | Train Accuracy: 96.90%
# Epoch 5: Train Loss: 0.085 | Train Accuracy: 97.72%
# ==> Evaluating on clean images..
# Accuracy on clean images: 95.34%
# Accuracy on FGSM adversarial examples: 72.89%
# Accuracy on PGD adversarial examples: 39.63%
# Accuracy on CW adversarial examples: 30.33%

# %% [markdown]
# VGG19

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision import models
import random

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare SVHN dataset
from torchvision.datasets import SVHN

transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale to 224x224 to match ImageNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

trainset = SVHN(root='./data', split='train', download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = SVHN(root='./data', split='test', download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load pretrained VGG19 model and adjust for SVHN
print('==> Loading pretrained VGG19 model..')
net = models.vgg19(pretrained=True)
net.classifier[6] = nn.Linear(4096, 10)  # Adjust final layer for SVHN (10 classes)
net = net.to(device)

# Fine-tune the model on SVHN
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Starting fine-tuning on SVHN..")
for epoch in range(25):  # Adjust number of epochs as needed
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define FGSM and PGD attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Carlini-Wagner attack function
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.01):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach()
    adv_images.requires_grad = True
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):
        outputs = model(adv_images)

        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            f_loss = torch.max((correct_class.unsqueeze(1) - outputs + kappa).clamp(min=0), dim=1)[0].mean()

        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        adv_images.data = torch.clamp(adv_images.data, 0, 1)

    return adv_images

# Test function to evaluate model accuracy on clean or adversarial examples
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate on clean images
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Parameters for FGSM, PGD, and C&W attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Testing the pretrained VGG19 model on FGSM, PGD, and C&W attacks
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained VGG19 Accuracy on Clean and Adversarial Examples (SVHN)')
plt.show()
# Out:
# Using downloaded and verified file: ./data/train_32x32.mat
# Using downloaded and verified file: ./data/test_32x32.mat
# ==> Loading pretrained VGG19 model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 221MB/s]
# ==> Starting fine-tuning on SVHN..
# Epoch 1: Train Loss: 0.619 | Train Accuracy: 79.63%
# Epoch 2: Train Loss: 0.271 | Train Accuracy: 91.87%
# Epoch 3: Train Loss: 0.223 | Train Accuracy: 93.47%
# Epoch 4: Train Loss: 0.192 | Train Accuracy: 94.39%
# Epoch 5: Train Loss: 0.172 | Train Accuracy: 95.14%
# Epoch 6: Train Loss: 0.155 | Train Accuracy: 95.61%
# Epoch 7: Train Loss: 0.137 | Train Accuracy: 96.06%
# Epoch 8: Train Loss: 0.126 | Train Accuracy: 96.47%
# Epoch 9: Train Loss: 0.113 | Train Accuracy: 96.80%
# Epoch 10: Train Loss: 0.100 | Train Accuracy: 97.16%
# Epoch 11: Train Loss: 0.089 | Train Accuracy: 97.56%
# Epoch 12: Train Loss: 0.079 | Train Accuracy: 97.77%
# Epoch 13: Train Loss: 0.071 | Train Accuracy: 97.97%
# Epoch 14: Train Loss: 0.065 | Train Accuracy: 98.09%
# Epoch 15: Train Loss: 0.059 | Train Accuracy: 98.26%
# Epoch 16: Train Loss: 0.051 | Train Accuracy: 98.51%
# Epoch 17: Train Loss: 0.046 | Train Accuracy: 98.58%
# Epoch 18: Train Loss: 0.043 | Train Accuracy: 98.69%
# Epoch 19: Train Loss: 0.039 | Train Accuracy: 98.78%
# Epoch 20: Train Loss: 0.033 | Train Accuracy: 98.97%
# Epoch 21: Train Loss: 0.034 | Train Accuracy: 98.91%
# Epoch 22: Train Loss: 0.027 | Train Accuracy: 99.15%
# Epoch 23: Train Loss: 0.026 | Train Accuracy: 99.20%
# Epoch 24: Train Loss: 0.024 | Train Accuracy: 99.21%
# Epoch 25: Train Loss: 0.026 | Train Accuracy: 99.12%
# ==> Evaluating on clean images..
# Accuracy on clean images: 95.37%
# Accuracy on FGSM adversarial examples: 62.63%
# Accuracy on PGD adversarial examples: 47.61%
# Accuracy on CW adversarial examples: 66.86%

# %% [markdown]
# MobilenetV2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision import models
import random

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare SVHN dataset
from torchvision.datasets import SVHN

transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale to 224x224 to match ImageNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.4377, 0.4438, 0.4728), (0.198, 0.201, 0.197)),  # SVHN mean and std
])

trainset = SVHN(root='./data', split='train', download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)

testset = SVHN(root='./data', split='test', download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Load pretrained MobileNetV2 model and adjust for SVHN
print('==> Loading pretrained MobileNetV2 model..')
net = models.mobilenet_v2(pretrained=True)
net.classifier[1] = nn.Linear(net.last_channel, 10)  # Adjust final layer for SVHN (10 classes)
net = net.to(device)

# Fine-tune the model on SVHN
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Starting fine-tuning on SVHN..")
for epoch in range(10):  # Adjust number of epochs as needed
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print(f"Epoch {epoch+1}: Train Loss: {train_loss/len(trainloader):.3f} | Train Accuracy: {100.*correct/total:.2f}%")

# Define FGSM and PGD attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Carlini-Wagner attack function
def carlini_wagner_attack(model, images, labels, targeted=False, c=1e-4, kappa=0, num_iter=100, learning_rate=0.02):
    images = images.clone().detach().to(device)
    labels = labels.to(device)
    adv_images = images.clone().detach()
    adv_images.requires_grad = True
    optimizer = optim.Adam([adv_images], lr=learning_rate)

    for _ in range(num_iter):
        outputs = model(adv_images)

        if targeted:
            target_class = labels
            f_loss = torch.max((outputs - outputs.gather(1, target_class.view(-1, 1)).squeeze() + kappa).clamp(min=0))
        else:
            correct_class = outputs.gather(1, labels.view(-1, 1)).squeeze()
            f_loss = torch.max((correct_class.unsqueeze(1) - outputs + kappa).clamp(min=0), dim=1)[0].mean()

        l2_loss = torch.norm((adv_images - images).view(images.size(0), -1), dim=1).mean()
        loss = l2_loss + c * f_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        adv_images.data = torch.clamp(adv_images.data, 0, 1)

    return adv_images

# Test function to evaluate model accuracy on clean or adversarial examples
def test_adversarial(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    if attack:
        print(f'Accuracy on {attack} adversarial examples: {acc:.2f}%')
    else:
        print(f'Accuracy on clean images: {acc:.2f}%')
    return acc

# Evaluate on clean images
print("==> Evaluating on clean images..")
acc_clean = test_adversarial(net)

# Parameters for FGSM, PGD, and C&W attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Testing the pretrained MobileNetV2 model on FGSM, PGD, and C&W attacks
acc_fgsm = test_adversarial(net, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial(net, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
acc_cw = test_adversarial(net, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD', 'C&W']
accuracies = [acc_clean, acc_fgsm, acc_pgd, acc_cw]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Pretrained MobileNetV2 Accuracy on Clean and Adversarial Examples (SVHN)')
plt.show()
# Out:
# Using downloaded and verified file: ./data/train_32x32.mat
# Using downloaded and verified file: ./data/test_32x32.mat
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# ==> Loading pretrained MobileNetV2 model..
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 144MB/s]
# ==> Starting fine-tuning on SVHN..
# Epoch 1: Train Loss: 0.713 | Train Accuracy: 76.89%
# Epoch 2: Train Loss: 0.256 | Train Accuracy: 92.38%
# Epoch 3: Train Loss: 0.201 | Train Accuracy: 94.24%
# Epoch 4: Train Loss: 0.168 | Train Accuracy: 95.23%
# Epoch 5: Train Loss: 0.142 | Train Accuracy: 96.07%
# Epoch 6: Train Loss: 0.121 | Train Accuracy: 96.72%
# Epoch 7: Train Loss: 0.100 | Train Accuracy: 97.27%
# Epoch 8: Train Loss: 0.081 | Train Accuracy: 97.81%
# Epoch 9: Train Loss: 0.065 | Train Accuracy: 98.27%
# Epoch 10: Train Loss: 0.052 | Train Accuracy: 98.63%
# ==> Evaluating on clean images..
# Accuracy on clean images: 94.67%
# Accuracy on FGSM adversarial examples: 71.52%
# Accuracy on PGD adversarial examples: 27.69%
# Accuracy on CW adversarial examples: 6.53%
# Accuracy on CW adversarial examples: 6.53%

# %% [markdown]
# # Diffensive Distilations

# %% [markdown]
# Restnet18

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import matplotlib.pyplot as plt
import numpy as np

# Set random seeds for reproducibility (ensures consistent results each run)
torch.manual_seed(0)
np.random.seed(0)

# Device configuration: Use GPU if available, otherwise fallback to CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare CIFAR-100 data with transformations for input normalization and resizing
transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale images to 224x224 (compatible with ResNet18 pre-trained on ImageNet)
    transforms.ToTensor(),  # Convert images to tensors
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),  # Normalize using dataset mean/std
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

# Download and load CIFAR-100 training data
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=0)  # Use smaller batch size for memory efficiency

# Download and load CIFAR-100 test data
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=0)

# Load ResNet18 as the teacher model
print('==> Loading pretrained ResNet18 model as the teacher model..')
teacher_model = models.resnet18(pretrained=True)  # Load pre-trained ResNet18
teacher_model.fc = nn.Linear(512, 100)  # Replace the last layer to match 100 classes in CIFAR-100
teacher_model = teacher_model.to(device)  # Move the model to the appropriate device (GPU/CPU)

# Define the loss function and optimizer for training the teacher model
criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.SGD(teacher_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)  # Stochastic Gradient Descent

# Train the teacher model with fine-tuning
print("==> Fine-tuning the teacher model..")
for epoch in range(2):  # Train for 2 epochs (reduced for faster training in this example)
    teacher_model.train()  # Put the model in training mode
    for inputs, targets in trainloader:  # Loop through batches of training data
        inputs, targets = inputs.to(device), targets.to(device)  # Move data to the appropriate device
        optimizer.zero_grad()  # Clear gradients from the last step
        outputs = teacher_model(inputs)  # Forward pass: Get predictions
        loss = criterion(outputs, targets)  # Compute loss
        loss.backward()  # Backpropagation: Compute gradients
        optimizer.step()  # Update model parameters

# Function to generate soft labels using the teacher model
def generate_soft_labels(model, dataloader, temperature=10):
    soft_labels = []  # List to store soft labels
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)  # Move data to device
        with torch.no_grad():  # No gradients needed
            outputs = model(inputs) / temperature  # Scale logits by temperature
            soft_labels.append((inputs, torch.softmax(outputs, dim=1)))  # Store soft labels
    return soft_labels

soft_train_labels = generate_soft_labels(teacher_model, trainloader)  # Generate soft labels for training data

# Load ResNet18 as the student model
student_model = models.resnet18(pretrained=True)
student_model.fc = nn.Linear(512, 100)  # Replace the last layer for CIFAR-100
student_model = student_model.to(device)

# Define optimizer for the student model
optimizer = optim.SGD(student_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

# Train the student model using defensive distillation
def train_student(model, soft_labels, temperature=10):
    model.train()  # Put the model in training mode
    for epoch in range(2):  # Train for 2 epochs (reduced for faster training)
        total_loss = 0  # Initialize total loss
        for inputs, soft_targets in soft_labels:
            inputs, soft_targets = inputs.to(device), soft_targets.to(device)  # Move data to device
            optimizer.zero_grad()  # Clear gradients
            outputs = model(inputs) / temperature  # Scale logits by temperature
            loss = nn.KLDivLoss()(torch.log_softmax(outputs, dim=1), soft_targets)  # Compute KL divergence loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update parameters
            total_loss += loss.item()  # Accumulate loss
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(soft_labels):.3f}")  # Print average loss per epoch

print("==> Training the student model with defensive distillation..")
train_student(student_model, soft_train_labels)  # Train student model

# Function to perform FGSM attack
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)  # Clone input and enable gradient computation
    output = model(x_adv)  # Get model predictions
    loss = criterion(output, y)  # Compute loss
    model.zero_grad()  # Clear gradients
    loss.backward()  # Compute gradients
    x_adv = x_adv + epsilon * x_adv.grad.sign()  # Apply adversarial perturbation
    x_adv = torch.clamp(x_adv, 0, 1)  # Clip values to valid range [0, 1]
    return x_adv

# Function to perform PGD attack
def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)  # Clone input and enable gradient computation
    for _ in range(num_iter):  # Perform multiple iterations
        output = model(x_adv)  # Get predictions
        loss = criterion(output, y)  # Compute loss
        model.zero_grad()  # Clear gradients
        loss.backward()  # Compute gradients
        x_adv = x_adv + alpha * x_adv.grad.sign()  # Apply perturbation
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)  # Clip perturbation to epsilon-ball
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)  # Clip to valid range and detach
    return x_adv

# Test the model under clean and adversarial conditions
def test_adversarial_defense(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0  # Count of correct predictions
    total = 0  # Total samples
    model.eval()  # Put model in evaluation mode
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)  # Move data to device

        # Apply the specified attack if any
        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)

        outputs = model(inputs)  # Get model predictions
        _, predicted = outputs.max(1)  # Get class with highest probability
        total += targets.size(0)  # Increment total samples
        correct += predicted.eq(targets).sum().item()  # Increment correct predictions

    acc = 100 * correct / total  # Compute accuracy
    print(f'Accuracy on {attack if attack else "clean"} examples: {acc:.2f}%')  # Print accuracy
    return acc

# Parameters for adversarial attacks
epsilon_fgsm = 0.1  # Perturbation size for FGSM
epsilon_pgd = 2 / 255  # Perturbation size for PGD
alpha = 2 / 255  # Step size for PGD
num_iter = 5  # Number of PGD iterations

# Evaluate the student model under adversarial attacks
print("==> Evaluating the student model under adversarial attacks..")
acc_clean = test_adversarial_defense(student_model)  # Test on clean data
acc_fgsm = test_adversarial_defense(student_model, attack='FGSM', epsilon=epsilon_fgsm)  # Test on FGSM adversarial examples
acc_pgd = test_adversarial_defense(student_model, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)  # Test on PGD adversarial examples

# Plot results
attacks = ['Clean', 'FGSM', 'PGD']  # Attack types
accuracies = [acc_clean, acc_fgsm, acc_pgd]  # Corresponding accuracies
plt.bar(attacks, accuracies)  # Create bar plot
plt.xlabel('Attack')  # X-axis label
plt.ylabel('Accuracy (%)')  # Y-axis label
plt.title('Defensive Distillation with ResNet18 (CIFAR-100)')  # Plot title
plt.show()  # Display the plot
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:13<00:00, 12.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Loading pretrained ResNet18 model as the teacher model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 188MB/s]
# ==> Fine-tuning the teacher model..
# ==> Training the student model with defensive distillation..
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:3369: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Epoch 1: Loss: 0.000
# Epoch 2: Loss: 0.000
# ==> Evaluating the student model under adversarial attacks..
# Accuracy on clean examples: 1.05%
# Accuracy on FGSM examples: 1.30%
# Accuracy on PGD examples: 0.04%

# %% [markdown]
# VGG19

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import matplotlib.pyplot as plt
import numpy as np

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Prepare CIFAR-100 data
transform_train = transforms.Compose([
    transforms.Resize(224),  # Rescale to 224x224 to match ImageNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=0)  # Reduced batch size and num_workers

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=0)

# Load pretrained VGG19 model and adjust for CIFAR-100
print('==> Loading pretrained VGG19 model as the teacher model..')
teacher_model = models.vgg19(pretrained=True)
teacher_model.classifier[6] = nn.Linear(4096, 100)  # Adjust the final layer for CIFAR-100
teacher_model = teacher_model.to(device)

# Train the teacher model (pretrained VGG19)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(teacher_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

print("==> Fine-tuning the teacher model..")
for epoch in range(2):  # Reduced epochs for faster training
    teacher_model.train()
    for inputs, targets in trainloader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = teacher_model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

# Generate soft labels with temperature
def generate_soft_labels(model, dataloader, temperature=10):
    soft_labels = []
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        with torch.no_grad():
            outputs = model(inputs) / temperature
            soft_labels.append((inputs, torch.softmax(outputs, dim=1)))
    return soft_labels

soft_train_labels = generate_soft_labels(teacher_model, trainloader)

# Train the distilled (student) model
student_model = models.vgg19(pretrained=True)
student_model.classifier[6] = nn.Linear(4096, 100)  # Adjust the final layer for CIFAR-100
student_model = student_model.to(device)

optimizer = optim.SGD(student_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

def train_student(model, soft_labels, temperature=10):
    model.train()
    for epoch in range(2):  # Reduced epochs for faster training
        total_loss = 0
        for inputs, soft_targets in soft_labels:
            inputs, soft_targets = inputs.to(device), soft_targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs) / temperature
            loss = nn.KLDivLoss()(torch.log_softmax(outputs, dim=1), soft_targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(soft_labels):.3f}")

print("==> Training the student model with defensive distillation..")
train_student(student_model, soft_train_labels)

# FGSM, PGD, and CW attack functions
def fgsm_attack(model, x, y, epsilon):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    output = model(x_adv)
    loss = criterion(output, y)
    model.zero_grad()
    loss.backward()
    x_adv = x_adv + epsilon * x_adv.grad.sign()
    x_adv = torch.clamp(x_adv, 0, 1)
    return x_adv

def pgd_attack(model, x, y, alpha, epsilon, num_iter):
    x_adv = x.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output = model(x_adv)
        loss = criterion(output, y)
        model.zero_grad()
        loss.backward()
        x_adv = x_adv + alpha * x_adv.grad.sign()
        eta = torch.clamp(x_adv - x, min=-epsilon, max=epsilon)
        x_adv = torch.clamp(x + eta, 0, 1).detach_().requires_grad_(True)
    return x_adv

# Test the student model under adversarial attacks
def test_adversarial_defense(model, attack=None, epsilon=None, alpha=None, num_iter=None):
    correct = 0
    total = 0
    model.eval()
    for inputs, targets in testloader:
        inputs, targets = inputs.to(device), targets.to(device)

        if attack == 'FGSM':
            inputs = fgsm_attack(model, inputs, targets, epsilon)
        elif attack == 'PGD':
            inputs = pgd_attack(model, inputs, targets, alpha, epsilon, num_iter)
        elif attack == 'CW':
            inputs = carlini_wagner_attack(model, inputs, targets, targeted=False, num_iter=100, learning_rate=0.01)

        outputs = model(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    acc = 100 * correct / total
    print(f'Accuracy on {attack if attack else "clean"} examples: {acc:.2f}%')
    return acc

# Parameters for FGSM, PGD, and CW attacks
epsilon_fgsm = 0.1
epsilon_pgd = 2 / 255
alpha = 2 / 255
num_iter = 5

# Test the student model
print("==> Evaluating the student model under adversarial attacks..")
acc_clean = test_adversarial_defense(student_model)
acc_fgsm = test_adversarial_defense(student_model, attack='FGSM', epsilon=epsilon_fgsm)
acc_pgd = test_adversarial_defense(student_model, attack='PGD', epsilon=epsilon_pgd, alpha=alpha, num_iter=num_iter)
#acc_cw = test_adversarial_defense(student_model, attack='CW')

# Plot results
attacks = ['Clean', 'FGSM', 'PGD']
accuracies = [acc_clean, acc_fgsm, acc_pgd]
plt.bar(attacks, accuracies)
plt.xlabel('Attack')
plt.ylabel('Accuracy (%)')
plt.title('Defensive Distillation with VGG19 (CIFAR-100)')
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.02MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Loading pretrained VGG19 model as the teacher model..
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:03<00:00, 185MB/s]
# ==> Fine-tuning the teacher model..
# ==> Training the student model with defensive distillation..
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:3369: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Epoch 1: Loss: 0.000
# Epoch 2: Loss: 0.000
# ==> Evaluating the student model under adversarial attacks..
# Accuracy on clean examples: 0.88%
# Accuracy on FGSM examples: 0.56%
# Accuracy on PGD examples: 0.03%
